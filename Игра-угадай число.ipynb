# %%
import random

def guess_the_number():
    print("Добро пожаловать в игру 'Угадай число'!")
    print("Я загадал число от 1 до 100. Попробуй угадать.")

    # Загадываем случайное число
    secret_number = random.randint(1, 100)

    attempts = 0

    while True:
        # Попытка угадать число
        guess = int(input("Ваш вариант: "))
        attempts += 1

        # Проверка угадано ли число
        if guess == secret_number:
            print(f"Поздравляю! Вы угадали число {secret_number} за {attempts} попыток.")
            break
        elif guess < secret_number:
            print("Нет, загаданное число больше.")
        else:
            print("Нет, загаданное число меньше.")

if __name__ == "__main__":
    guess_the_number()
# Out:
# Добро пожаловать в игру 'Угадай число'!
# Я загадал число от 1 до 100. Попробуй угадать.
# Ваш вариант: 6
# Нет, загаданное число больше.
# Ваш вариант: 500
# Нет, загаданное число меньше.
# Ваш вариант: 200
# Нет, загаданное число меньше.
# Ваш вариант: 100
# Нет, загаданное число меньше.
# Ваш вариант: 50
# Нет, загаданное число меньше.
# Ваш вариант: 20
# Нет, загаданное число больше.
# Ваш вариант: 30
# Нет, загаданное число меньше.
# Ваш вариант: 25
# Нет, загаданное число меньше.
# Ваш вариант: 22
# Поздравляю! Вы угадали число 22 за 9 попыток.
